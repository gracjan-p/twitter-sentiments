# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('./twitter.csv', index_col=0)
df
# Out:
#                                                      text  label
# 0           i just feel really helpless and heavy hearted      4
# 1       ive enjoyed being able to slouch about relax a...      0
# 2       i gave up my internship with the dmrg and am f...      4
# 3                              i dont know i feel so lost      0
# 4       i am a kindergarten teacher and i am thoroughl...      4
# ...                                                   ...    ...
# 416804  i feel like telling these horny devils to find...      2
# 416805  i began to realize that when i was feeling agi...      3
# 416806  i feel very curious be why previous early dawn...      5
# 416807  i feel that becuase of the tyranical nature of...      3
# 416808  i think that after i had spent some time inves...      5
#
# [416809 rows x 2 columns]

# %%
df['len'] = df['text'].apply(lambda text: len(text.split()))
plot_words = sns.displot(df['len'], bins=50, aspect=2, kde=True)
plt.xlim(0, 80)
plt.show()

from scipy.stats import hmean, trim_mean
a_mean = int(df['len'].mean())
t_mean = int(trim_mean(df['len'], 0.2))
h_mean = int(hmean(df['len']))
print(f"a_mean = {a_mean}\n"
      f"t_mean = {t_mean}\n"
      f"h_mean = {h_mean}")

df
# Out:
# a_mean = 19
# t_mean = 17
# h_mean = 13
#                                                      text  label  len
# 0           i just feel really helpless and heavy hearted      4    8
# 1       ive enjoyed being able to slouch about relax a...      0   45
# 2       i gave up my internship with the dmrg and am f...      4   12
# 3                              i dont know i feel so lost      0    7
# 4       i am a kindergarten teacher and i am thoroughl...      4   42
# ...                                                   ...    ...  ...
# 416804  i feel like telling these horny devils to find...      2   26
# 416805  i began to realize that when i was feeling agi...      3   23
# 416806  i feel very curious be why previous early dawn...      5   19
# 416807  i feel that becuase of the tyranical nature of...      3   41
# 416808  i think that after i had spent some time inves...      5   23
#
# [416809 rows x 3 columns]

# %%
train = df.drop('len', axis=1)
test = df.drop('len', axis=1)

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB, BernoulliNB, ComplementNB
from sklearn.pipeline import make_pipeline

model = make_pipeline(TfidfVectorizer(), ComplementNB())
model.fit(train.text, train.label)
labels = model.predict(test.text)

# %%
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score
mat = confusion_matrix(test.label, labels)
sns.heatmap(mat.T, annot=True, fmt='d', square=True, cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label')

f1 = f1_score(test.label, labels, average='weighted')
print(f1)
# Out:
# 0.9062265283336653
